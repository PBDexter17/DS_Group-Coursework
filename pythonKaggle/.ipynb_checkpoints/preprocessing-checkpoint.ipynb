# %%
import numpy as np
import pandas as pd
global_path = '/Users/sujie/Desktop/pythonKaggle'

# %%
#read the csv file
df_train = pd.read_csv(global_path+'/data/train_users_2.csv')
df_test = pd.read_csv(global_path+'/data/test_users.csv')
age_gender_bkts = pd.read_csv(global_path+'/data/age_gender_bkts.csv')
countries = pd.read_csv(global_path+'/data/countries.csv')
sessions = pd.read_csv(global_path+'/data/sessions.csv')

# %%
#set label as the id  and the country destination
labels = df_train[['id','country_destination']]

# %%
#set the destination of the test data as nan
df_test = df_test.assign(country_destination=np.nan)

# %%
#set the dataset type
df_test = df_test.assign(dataset = "test")
df_train = df_train.assign(dataset = "train")

# %%
#combine the training data and test data
df_all = df_train.append(df_test)

# %%
#clean the age
age = df_all['age'].tolist()
#clean bad age data which is define in year such as 2014 or ...
#using this data is collect in 2015 so we use 2015 as a point to calculate the age who
#use birth year as their date. so the age_cln feature means real age
age_cln = [2015 - x if x >= 1920 else x for x in age]
#create a feature wihch define the childrens and people whose age is greater than 100 as -1
#others keep real age
age_cln2 = [-1 if x<14 or x>100 else x for x in age_cln]
df_age_cln = pd.DataFrame()
df_age_cln2 = pd.DataFrame()
df_age_cln = df_age_cln.assign(age_cln = age_cln)
df_age_cln = df_age_cln.assign(age_cln2 = age_cln2)
#add df_age_cln into df_all dataframe
df_all = pd.concat([df_all.reset_index(drop = True),df_age_cln],axis = 1)
df_all = pd.concat([df_all.reset_index(drop = True),df_age_cln2],axis = 1)

# %%
# Out:
#                 id date_account_created  timestamp_first_active  \
# 0       gxn3p5htnn            2010/6/28          20090300000000
# 1       820tgsjxq7            2011/5/25          20090500000000
# 2       4ft3gnwmtx            2010/9/28          20090600000000
# 3       bjjt8pjhuk            2011/12/5          20091000000000
# 4       87mebub9p4            2010/9/14          20091200000000
# 5       osr2jwljor             2010/1/1          20100100000000
# 6       lsw9q7uk0j             2010/1/2          20100100000000
# 7       0d01nltbrs             2010/1/3          20100100000000
# 8       a1vcnhxeij             2010/1/4          20100100000000
# 9       6uh8zyj2gn             2010/1/4          20100100000000
# 10      yuuqmid2rp             2010/1/4          20100100000000
# 11      om1ss59ys8             2010/1/5          20100100000000
# 12      k6np330cm1             2010/1/5          20100100000000
# 13      dy3rgx56cu             2010/1/5          20100100000000
# 14      ju3h98ch3w             2010/1/7          20100100000000
# 15      v4d5rl22px             2010/1/7          20100100000000
# 16      2dwbwkx056             2010/1/7          20100100000000
# 17      frhre329au             2010/1/7          20100100000000
# 18      cxlg85pg1r             2010/1/8          20100100000000
# 19      gdka1q5ktd            2010/1/10          20100100000000
# 20      qdubonn3uk            2010/1/10          20100100000000
# 21      qsibmuz9sx            2010/1/10          20100100000000
# 22      80f7dwscrn            2010/1/11          20100100000000
# 23      jha93x042q            2010/1/11          20100100000000
# 24      7i49vnuav6            2010/1/11          20100100000000
# 25      al8bcetz0g            2010/1/12          20100100000000
# 26      bjg0m5otl3            2010/1/12          20100100000000
# 27      hfrl5gle36            2010/1/12          20100100000000
# 28      tp6x3md0n4            2010/1/13          20100100000000
# 29      hql77nu2lk            2010/1/13          20100100000000
# ...            ...                  ...                     ...
# 275517  bsv2ev628t           2014/09/30          20140900000000
# 275518  06echc56pl           2014/09/30          20140900000000
# 275519  niqgaye2ov           2014/09/30          20140900000000
# 275520  61iwzuhw6e           2014/09/30          20140900000000
# 275521  gks02el96u           2014/09/30          20140900000000
# 275522  v4r1161l0r           2014/09/30          20140900000000
# 275523  p1clbqd0o6           2014/09/30          20140900000000
# 275524  ozb2z0km6l           2014/09/30          20140900000000
# 275525  w3e3sp6i70           2014/09/30          20140900000000
# 275526  q5bxbq0asg           2014/09/30          20140900000000
# 275527  1xa5t3t0la           2014/09/30          20140900000000
# 275528  zuvz7gfpjz           2014/09/30          20140900000000
# 275529  gpusl6ppgf           2014/09/30          20140900000000
# 275530  gpijioh4eh           2014/09/30          20140900000000
# 275531  3ptlvdxss9           2014/09/30          20140900000000
# 275532  f9a1ncjnrg           2014/09/30          20140900000000
# 275533  kofaz2kh70           2014/09/30          20140900000000
# 275534  6xrmom7hjo           2014/09/30          20140900000000
# 275535  cg9wqgnad2           2014/09/30          20140900000000
# 275536  jg618z94wo           2014/09/30          20140900000000
# 275537  u7lv3glv6y           2014/09/30          20140900000000
# 275538  o6ofmozucx           2014/09/30          20140900000000
# 275539  wcw7xggeqp           2014/09/30          20140900000000
# 275540  m22pw2pkxr           2014/09/30          20140900000000
# 275541  8yvhec201j           2014/09/30          20140900000000
# 275542  cv0na2lf5a           2014/09/30          20140900000000
# 275543  zp8xfonng8           2014/09/30          20140900000000
# 275544  fa6260ziny           2014/09/30          20140900000000
# 275545  87k0fy4ugm           2014/09/30          20140900000000
# 275546  9uqfg8txu3           2014/09/30          20140900000000
#
#        date_first_booking     gender   age signup_method  signup_flow  \
# 0                     NaN  -unknown-   NaN      facebook            0
# 1                     NaN       MALE  38.0      facebook            0
# 2                2010/8/2     FEMALE  56.0         basic            3
# 3                2012/9/8     FEMALE  42.0      facebook            0
# 4               2010/2/18  -unknown-  41.0         basic            0
# 5                2010/1/2  -unknown-   NaN         basic            0
# 6                2010/1/5     FEMALE  46.0         basic            0
# 7               2010/1/13     FEMALE  47.0         basic            0
# 8               2010/7/29     FEMALE  50.0         basic            0
# 9                2010/1/4  -unknown-  46.0         basic            0
# 10               2010/1/6     FEMALE  36.0         basic            0
# 11                    NaN     FEMALE  47.0         basic            0
# 12              2010/1/18  -unknown-   NaN         basic            0
# 13                    NaN     FEMALE  37.0         basic            0
# 14                    NaN     FEMALE  36.0         basic            0
# 15               2010/1/8     FEMALE  33.0         basic            0
# 16                    NaN  -unknown-   NaN         basic            0
# 17               2010/1/9  -unknown-  31.0         basic            0
# 18                    NaN  -unknown-   NaN         basic            0
# 19              2010/1/10     FEMALE  29.0         basic            0
# 20              2010/1/18  -unknown-   NaN         basic            0
# 21              2010/1/11       MALE  30.0         basic            0
# 22              2010/1/11  -unknown-  40.0         basic            0
# 23                    NaN  -unknown-   NaN         basic            0
# 24                    NaN     FEMALE  40.0         basic            0
# 25              2010/1/15     FEMALE  26.0         basic            0
# 26                    NaN  -unknown-   NaN         basic            0
# 27              2010/1/22     FEMALE  32.0         basic            0
# 28              2010/1/13  -unknown-  35.0         basic            0
# 29              2010/1/19  -unknown-  37.0         basic            0
# ...                   ...        ...   ...           ...          ...
# 275517                NaN  -unknown-   NaN        google           12
# 275518                NaN     FEMALE  48.0         basic            0
# 275519                NaN  -unknown-   NaN         basic            0
# 275520                NaN     FEMALE  24.0      facebook           25
# 275521                NaN     FEMALE  32.0      facebook            0
# 275522                NaN  -unknown-   NaN         basic            0
# 275523                NaN  -unknown-   NaN         basic           23
# 275524                NaN  -unknown-   NaN         basic           23
# 275525                NaN  -unknown-   NaN         basic            0
# 275526                NaN     FEMALE  40.0      facebook            0
# 275527                NaN       MALE  39.0      facebook            0
# 275528                NaN  -unknown-   NaN         basic            0
# 275529                NaN  -unknown-   NaN         basic            0
# 275530                NaN       MALE  44.0         basic            0
# 275531                NaN  -unknown-  39.0         basic            0
# 275532                NaN     FEMALE  34.0      facebook           23
# 275533                NaN  -unknown-   NaN         basic            0
# 275534                NaN       MALE  40.0      facebook           23
# 275535                NaN       MALE  27.0      facebook            0
# 275536                NaN     FEMALE  24.0      facebook            0
# 275537                NaN  -unknown-   NaN         basic           25
# 275538                NaN       MALE  55.0         basic            0
# 275539                NaN  -unknown-  34.0         basic            0
# 275540                NaN       MALE  32.0         basic            0
# 275541                NaN  -unknown-   NaN         basic            0
# 275542                NaN  -unknown-  31.0         basic            0
# 275543                NaN  -unknown-   NaN         basic           23
# 275544                NaN  -unknown-   NaN         basic            0
# 275545                NaN  -unknown-   NaN         basic            0
# 275546                NaN     FEMALE  49.0         basic            0
#
#        language affiliate_channel    ...    first_affiliate_tracked  \
# 0            en            direct    ...                  untracked
# 1            en               seo    ...                  untracked
# 2            en            direct    ...                  untracked
# 3            en            direct    ...                  untracked
# 4            en            direct    ...                  untracked
# 5            en             other    ...                        omg
# 6            en             other    ...                  untracked
# 7            en            direct    ...                        omg
# 8            en             other    ...                  untracked
# 9            en             other    ...                        omg
# 10           en             other    ...                  untracked
# 11           en             other    ...                  untracked
# 12           en            direct    ...                        NaN
# 13           en             other    ...                     linked
# 14           en             other    ...                  untracked
# 15           en            direct    ...                  untracked
# 16           en             other    ...                        NaN
# 17           en             other    ...                        NaN
# 18           en               seo    ...                        NaN
# 19           en            direct    ...                  untracked
# 20           en            direct    ...                        NaN
# 21           en            direct    ...                     linked
# 22           en               seo    ...                  untracked
# 23           en             other    ...                  untracked
# 24           en               seo    ...                  untracked
# 25           en             other    ...                  untracked
# 26           en             other    ...                  untracked
# 27           en             other    ...                  untracked
# 28           en            direct    ...                        NaN
# 29           en            direct    ...                  untracked
# ...         ...               ...    ...                        ...
# 275517       en            direct    ...                  untracked
# 275518       en            direct    ...                  untracked
# 275519       en               seo    ...                  untracked
# 275520       en            direct    ...                  untracked
# 275521       en               seo    ...                  untracked
# 275522       en            direct    ...                  untracked
# 275523       en            direct    ...                  untracked
# 275524       en            direct    ...                  untracked
# 275525       en            direct    ...                     linked
# 275526       en         sem-brand    ...                        omg
# 275527       en               seo    ...                  untracked
# 275528       en               seo    ...                  untracked
# 275529       en               seo    ...                  untracked
# 275530       en               seo    ...                     linked
# 275531       en               seo    ...                     linked
# 275532       en            direct    ...                  untracked
# 275533       en               seo    ...                  untracked
# 275534       en            direct    ...                  untracked
# 275535       en            direct    ...                  untracked
# 275536       en            direct    ...                     linked
# 275537       en            direct    ...                  untracked
# 275538       en         sem-brand    ...                        omg
# 275539       en            direct    ...                  untracked
# 275540       en            direct    ...                     linked
# 275541       en               seo    ...                     linked
# 275542       en            direct    ...                  untracked
# 275543       ko            direct    ...                  untracked
# 275544       de            direct    ...                     linked
# 275545       en         sem-brand    ...                        omg
# 275546       en             other    ...              tracked-other
#
#        signup_app first_device_type  first_browser country_destination  \
# 0             Web       Mac Desktop         Chrome                 NDF
# 1             Web       Mac Desktop         Chrome                 NDF
# 2             Web   Windows Desktop             IE                  US
# 3             Web       Mac Desktop        Firefox               other
# 4             Web       Mac Desktop         Chrome                  US
# 5             Web       Mac Desktop         Chrome                  US
# 6             Web       Mac Desktop         Safari                  US
# 7             Web       Mac Desktop         Safari                  US
# 8             Web       Mac Desktop         Safari                  US
# 9             Web       Mac Desktop        Firefox                  US
# 10            Web       Mac Desktop        Firefox                  US
# 11            Web            iPhone      -unknown-                 NDF
# 12            Web     Other/Unknown      -unknown-                  FR
# 13            Web       Mac Desktop        Firefox                 NDF
# 14            Web            iPhone  Mobile Safari                 NDF
# 15            Web   Windows Desktop         Chrome                  CA
# 16            Web     Other/Unknown      -unknown-                 NDF
# 17            Web     Other/Unknown      -unknown-                  US
# 18            Web     Other/Unknown      -unknown-                 NDF
# 19            Web       Mac Desktop         Chrome                  FR
# 20            Web     Other/Unknown      -unknown-                  US
# 21            Web       Mac Desktop         Chrome                  US
# 22            Web            iPhone      -unknown-                  US
# 23            Web       Mac Desktop         Safari                 NDF
# 24            Web       Mac Desktop        Firefox                 NDF
# 25            Web       Mac Desktop         Chrome                  FR
# 26            Web     Other/Unknown      -unknown-                 NDF
# 27            Web   Desktop (Other)         Chrome                  US
# 28            Web     Other/Unknown      -unknown-                  FR
# 29            Web    Android Tablet      -unknown-                  US
# ...           ...               ...            ...                 ...
# 275517    Android     Android Phone      -unknown-                 NaN
# 275518        Web       Mac Desktop         Safari                 NaN
# 275519        Web       Mac Desktop        Firefox                 NaN
# 275520        iOS            iPhone      -unknown-                 NaN
# 275521        Web              iPad  Mobile Safari                 NaN
# 275522      Moweb     Android Phone  Chrome Mobile                 NaN
# 275523    Android     Android Phone      -unknown-                 NaN
# 275524    Android     Android Phone      -unknown-                 NaN
# 275525      Moweb            iPhone  Mobile Safari                 NaN
# 275526        Web   Windows Desktop        Firefox                 NaN
# 275527        Web            iPhone  Mobile Safari                 NaN
# 275528        Web       Mac Desktop        Firefox                 NaN
# 275529        Web              iPad  Mobile Safari                 NaN
# 275530        Web       Mac Desktop         Chrome                 NaN
# 275531        Web   Windows Desktop        Firefox                 NaN
# 275532    Android     Android Phone      -unknown-                 NaN
# 275533        Web       Mac Desktop         Safari                 NaN
# 275534    Android     Android Phone      -unknown-                 NaN
# 275535        Web       Mac Desktop        Firefox                 NaN
# 275536        Web            iPhone  Mobile Safari                 NaN
# 275537        iOS            iPhone      -unknown-                 NaN
# 275538        Web   Windows Desktop        Firefox                 NaN
# 275539        Web       Mac Desktop         Chrome                 NaN
# 275540        Web   Windows Desktop         Chrome                 NaN
# 275541        Web   Windows Desktop         Chrome                 NaN
# 275542        Web   Windows Desktop             IE                 NaN
# 275543    Android     Android Phone      -unknown-                 NaN
# 275544        Web   Windows Desktop        Firefox                 NaN
# 275545        Web       Mac Desktop         Safari                 NaN
# 275546        Web   Windows Desktop         Chrome                 NaN
#
#        dataset  age_cln  age_cln  age_cln  age_cln2
# 0        train      NaN      NaN      NaN       NaN
# 1        train     38.0     38.0     38.0      38.0
# 2        train     56.0     56.0     56.0      56.0
# 3        train     42.0     42.0     42.0      42.0
# 4        train     41.0     41.0     41.0      41.0
# 5        train      NaN      NaN      NaN       NaN
# 6        train     46.0     46.0     46.0      46.0
# 7        train     47.0     47.0     47.0      47.0
# 8        train     50.0     50.0     50.0      50.0
# 9        train     46.0     46.0     46.0      46.0
# 10       train     36.0     36.0     36.0      36.0
# 11       train     47.0     47.0     47.0      47.0
# 12       train      NaN      NaN      NaN       NaN
# 13       train     37.0     37.0     37.0      37.0
# 14       train     36.0     36.0     36.0      36.0
# 15       train     33.0     33.0     33.0      33.0
# 16       train      NaN      NaN      NaN       NaN
# 17       train     31.0     31.0     31.0      31.0
# 18       train      NaN      NaN      NaN       NaN
# 19       train     29.0     29.0     29.0      29.0
# 20       train      NaN      NaN      NaN       NaN
# 21       train     30.0     30.0     30.0      30.0
# 22       train     40.0     40.0     40.0      40.0
# 23       train      NaN      NaN      NaN       NaN
# 24       train     40.0     40.0     40.0      40.0
# 25       train     26.0     26.0     26.0      26.0
# 26       train      NaN      NaN      NaN       NaN
# 27       train     32.0     32.0     32.0      32.0
# 28       train     35.0     35.0     35.0      35.0
# 29       train     37.0     37.0     37.0      37.0
# ...        ...      ...      ...      ...       ...
# 275517    test      NaN      NaN      NaN       NaN
# 275518    test     48.0     48.0     48.0      48.0
# 275519    test      NaN      NaN      NaN       NaN
# 275520    test     24.0     24.0     24.0      24.0
# 275521    test     32.0     32.0     32.0      32.0
# 275522    test      NaN      NaN      NaN       NaN
# 275523    test      NaN      NaN      NaN       NaN
# 275524    test      NaN      NaN      NaN       NaN
# 275525    test      NaN      NaN      NaN       NaN
# 275526    test     40.0     40.0     40.0      40.0
# 275527    test     39.0     39.0     39.0      39.0
# 275528    test      NaN      NaN      NaN       NaN
# 275529    test      NaN      NaN      NaN       NaN
# 275530    test     44.0     44.0     44.0      44.0
# 275531    test     39.0     39.0     39.0      39.0
# 275532    test     34.0     34.0     34.0      34.0
# 275533    test      NaN      NaN      NaN       NaN
# 275534    test     40.0     40.0     40.0      40.0
# 275535    test     27.0     27.0     27.0      27.0
# 275536    test     24.0     24.0     24.0      24.0
# 275537    test      NaN      NaN      NaN       NaN
# 275538    test     55.0     55.0     55.0      55.0
# 275539    test     34.0     34.0     34.0      34.0
# 275540    test     32.0     32.0     32.0      32.0
# 275541    test      NaN      NaN      NaN       NaN
# 275542    test     31.0     31.0     31.0      31.0
# 275543    test      NaN      NaN      NaN       NaN
# 275544    test      NaN      NaN      NaN       NaN
# 275545    test      NaN      NaN      NaN       NaN
# 275546    test     49.0     49.0     49.0      49.0
#
# [275547 rows x 21 columns]
